# %%
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer
from transformers import BertForSequenceClassification, LongformerTokenizer, LongformerForSequenceClassification
from torch import nn
import torch
from streamlit_utils import *
from datetime import datetime
#Model
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

#Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
# Apply the tokenizer to the input text, treating them as a text-pair.
def tokenize_input_text(question, input_text):

    input_ids = tokenizer.encode(question, input_text)

    return input_ids

# %%
def get_segment_ids(input_ids):
    # Search the input_ids for the first instance of the `[SEP]` token.
    sep_index = input_ids.index(tokenizer.sep_token_id)

    # The number of segment A tokens includes the [SEP] token istelf.
    num_seg_a = sep_index + 1

    # The remainder are segment B.
    num_seg_b = len(input_ids) - num_seg_a

    # Construct the list of 0s and 1s.
    segment_ids = [0]*num_seg_a + [1]*num_seg_b

    # There should be a segment_id for every input token.
    assert len(segment_ids) == len(input_ids)

    return segment_ids

# %%
def get_scores(input_ids,segment_ids):
    # Run through the model.
    start_scores, end_scores = model(torch.tensor([input_ids]), # The tokens representing our input text.
                                    token_type_ids=torch.tensor([segment_ids]),
                                    return_dict = False) # The segment IDs to differentiate question from answer_text
    return start_scores, end_scores

# %%
# Find the tokens with the highest `start` and `end` scores.
def get_answer(start_scores,end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)

    # Combine the tokens in the answer and print it out.
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = ' '.join(tokens[answer_start:answer_end+1])

    return answer

# %%
# Better version

def get_answer_clean(start_scores, end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = tokens[answer_start]

    # Select the remaining answer tokens and join them with whitespace.
    for i in range(answer_start + 1, answer_end + 1):
        
        # If it's a subword token, then recombine it with the previous token.
        if tokens[i][0:2] == '##':
            answer += tokens[i][2:]
        
        # Otherwise, add a space then the token.
        else:
            answer += ' ' + tokens[i]
    return answer

# %%
def answer_from_question(question, input_text):
    input_ids = tokenize_input_text(question, input_text)
    segment_ids = get_segment_ids(input_ids)
    start_scores, end_scores = get_scores(input_ids, segment_ids)

    res = get_answer_clean(start_scores, end_scores, input_ids)

    if '[CLS]' in res:
        return "No answer found"    
    return res

# %%
def get_first_senteces_from_sentences_list(sentences_list, nb_sentences):
    return "".join(sentences_list[0:nb_sentences])

# %%
def add_QA_location_to_df(df_location, subject, nb_sentences=9):
    question = "Where did the " + subject + " occur?"
    df_location["QA_location"] = None
    df_location["QA_location"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_impact_to_df(df_location, subject, nb_sentences=10):
    question = "What were the impact of the " + subject + " ?"
    df_location["QA_impact"] = None
    df_location["QA_impact"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_cause_to_df(df_location, subject, nb_sentences=10):
    question = "What caused the " + subject + " ?"
    df_location["QA_cause"] = None
    df_location["QA_cause"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
lf_tokenizer = LongformerTokenizer.from_pretrained("allenai/longformer-base-4096")
lf_model = torch.load('model/longformer_finetuned').to('cpu')

# %%
min_date = datetime(2011,1,1)
max_date = datetime(2012,1,1)
date_limits = (min_date, max_date)
subject = "wildfire"
nb_pages = 4
df_location = get_locations_df_from_subject(subject, nb_pages, lf_model, lf_tokenizer, date_limits)

df_location
# Out:
# Successfully scraped :  40  links
# Done scraping
# There are 23 usable articles
# There are 17 relevant articles
#                                                 Title  \
# 0   Texas Wildfires: 852 Homes Lost in 48 Hours - ...
# 1   Arizona Wildfire Pictures: Blaze Advancing on ...
# 2   Wild Facts About the Huge Arizona Wildfire | L...
# 3   New Mexico Wildfire Forces Los Alamos Lab to C...
# 4   Perry a No-Show at Texas Wildfire Press Confer...
# 5           Nuns Fight Washington Wildfire - ABC News
# 6                     Wildfire spared lucky residents
# 7   Smoke from Minnesota wildfire reaches Illinois...
# 8   Gov. Rick Perry sees Texas wildfires as statew...
# 9   Fire and punishment: Penalties for starting bi...
# 10    2 firefighters killed battling Florida wildfire
# 11   Israeli tourist: Wildfire in Chile not my fault
# 12  Oklahoma, Texas Wildfires Destroy Dozens of Ho...
# 13  Firefighters continue to fight catastrophic wi...
# 14  John McCain's Illegal Immigrants Started Arizo...
# 15  Firefighter response to Dollar Lake wildfire i...
# 16  Losses from Bastrop, Texas, Wildfire Rise to $...
#
#                                                  Link        Date  \
# 0   https://abcnews.go.com/US/texas-wildfires-852-...  2011-09-06
# 1   https://www.nationalgeographic.com/science/art...  2011-06-08
# 2   https://www.livescience.com/14508-arizona-wild...  2011-06-08
# 3   https://abcnews.go.com/US/mexico-wildfire-forc...  2011-06-28
# 4   https://www.texastribune.org/2011/09/10/perry-...  2011-09-10
# 5   http://abcnews.go.com/blogs/headlines/2011/09/...  2011-09-08
# 6   https://www.mysanantonio.com/news/local_news/a...  2011-04-12
# 7   https://www.chicagotribune.com/news/breaking/c...  2011-09-13
# 8   https://www.csmonitor.com/USA/2011/0425/Gov.-R...  2011-04-25
# 9   https://azdailysun.com/news/local/fire-and-pun...  2011-05-10
# 10  https://www.firerescue1.com/wildfire/articles/...  2020-06-05
# 11  https://www.ynetnews.com/articles/0,7340,L-416...  2012-01-01
# 12  https://abcnews.go.com/US/oklahoma-texas-wildf...  2011-08-31
# 13  https://www.chron.com/news/houston-texas/artic...  2011-09-07
# 14  https://abcnews.go.com/US/john-mccain-claims-i...  2011-06-19
# 15  https://www.oregonlive.com/environment/2011/09...  2011-09-14
# 16  https://www.claimsjournal.com/news/southcentra...  2011-12-12
#
#                                         Clean_content  \
# 0   In 2011,Texas experienced six of the 10 larges...
# 1   End of the Road? A wildfire blackens the sky a...
# 2    By   Live Science Staff   published 8 June 11...
# 6   [FORT DAVIS With West Texas roots that go back...
# 7   [Smoke from a forest fire in northeastern Minn...
# 8   [Loading...  April 25, 2011 In a strongly word...
# 9   [Transient Randall Nicholson is now serving mo...
# 10  [Officials say the injured forest rangers suff...
# 11  [Israeli tourist Rotem Singer, 23, suspected o...
# 12  [Dry and windy conditions spark devastating wi...
# 13  [Reed Griffith, of Montgomery Fire Rescue, hel...
# 14  [McCain said illegal aliens light fires to div...
# 15  [From her orchards on the flanks of Mount Hood...
# 16  [More than half of the homeowner insurance cla...
#
#                                              Location  \
# 0   [Texas, South Carolina, California, Bastrop Co...
# 1          [U.S., Luna, New Mexico, Arizona, Phoenix]
# 2   [Arizona, Manhattan, New York City, Greenlee C...
# 3                   [America, Los Alamos, New Mexico]
# 4   [Bastrop County, Austin, Texas, Perry, New Ham...
# 5                               [Washington, Seattle]
# 6   [Fort Davis, Presidio County, Texas, Rock Hous...
# 7   [Minnesota, Illinois, Wisconsin, Fall Lake, Mi...
# 8   [Texas, US, Perry, North Carolina, California,...
# 9   [U.S., Arizona, Texas, Highway, Oak Creek Canyon]
# 10  [Fla., Jasper, Florida, Hamilton County, Georg...
# 11                                  [Chile, Santiago]
# 12  [Texas, Oklahoma, Oklahoma City, Fort Worth, P...
# 13  [Waller County, Montgomery County, Magnolia, B...
# 14              [Arizona, the Arizona Republic, N.M.]
# 15  [Ore., Alaska, Segovia, Bambe, Portland, Washi...
# 16                                      [U.S., Texas]
#
#                                           QA_location
# 0                                 just east of austin
# 1                                   luna , new mexico
# 2                   apache sitgreaves national forest
# 3                                          los alamos
# 4   austin . by kate galbraith and jay root sept ....
# 5                                              golden
# 6                                     presidio county
# 7   boundary waters canoe area wilderness near fal...
# 8                                     No answer found
# 9                                 near wupatki trails
# 10                hamilton county on the georgia line
# 11     chile patagonia national park torres del paine
# 12                                      oklahoma city
# 13             south of todd mission in waller county
# 14                                            arizona
# 15                                         mount hood
# 16                                    bastrop complex

# %%
nb_sentences = 9
df_location = add_QA_impact_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   Texas Wildfires: 852 Homes Lost in 48 Hours - ...
# 1   Arizona Wildfire Pictures: Blaze Advancing on ...
# 2   Wild Facts About the Huge Arizona Wildfire | L...
# 3   New Mexico Wildfire Forces Los Alamos Lab to C...
# 4   Perry a No-Show at Texas Wildfire Press Confer...
# 5           Nuns Fight Washington Wildfire - ABC News
# 6                     Wildfire spared lucky residents
# 7   Smoke from Minnesota wildfire reaches Illinois...
# 8   Gov. Rick Perry sees Texas wildfires as statew...
# 9   Fire and punishment: Penalties for starting bi...
# 10    2 firefighters killed battling Florida wildfire
# 11   Israeli tourist: Wildfire in Chile not my fault
# 12  Oklahoma, Texas Wildfires Destroy Dozens of Ho...
# 13  Firefighters continue to fight catastrophic wi...
# 14  John McCain's Illegal Immigrants Started Arizo...
# 15  [From her orchards on the flanks of Mount Hood...
# 16  [More than half of the homeowner insurance cla...
#
#                                              Location  \
# 0   [Texas, South Carolina, California, Bastrop Co...
# 1          [U.S., Luna, New Mexico, Arizona, Phoenix]
# 2   [Arizona, Manhattan, New York City, Greenlee C...
# 3                   [America, Los Alamos, New Mexico]
# 4   [Bastrop County, Austin, Texas, Perry, New Ham...
# 5                               [Washington, Seattle]
# 6   [Fort Davis, Presidio County, Texas, Rock Hous...
# 7   [Minnesota, Illinois, Wisconsin, Fall Lake, Mi...
# 8   [Texas, US, Perry, North Carolina, California,...
# 9   [U.S., Arizona, Texas, Highway, Oak Creek Canyon]
# 10  [Fla., Jasper, Florida, Hamilton County, Georg...
# 11                                  [Chile, Santiago]
# 12  [Texas, Oklahoma, Oklahoma City, Fort Worth, P...
# 13  [Waller County, Montgomery County, Magnolia, B...
# 14              [Arizona, the Arizona Republic, N.M.]
# 15  [Ore., Alaska, Segovia, Bambe, Portland, Washi...
# 16                                      [U.S., Texas]
#
#                                           QA_location  \
# 0                                 just east of austin
# 1                                   luna , new mexico
# 2                   apache sitgreaves national forest
# 3                                          los alamos
# 4   austin . by kate galbraith and jay root sept ....
# 5                                              golden
# 6                                     presidio county
# 7   boundary waters canoe area wilderness near fal...
# 8                                     No answer found
# 9                                 near wupatki trails
# 10                hamilton county on the georgia line
# 11     chile patagonia national park torres del paine
# 12                                      oklahoma city
# 13             south of todd mission in waller county
# 14                                            arizona
# 15                                         mount hood
# 16                                    bastrop complex
#
#                                             QA_impact
# 0   burned at least 600 homes and blackened 30 , 0...
# 1   the blaze forced the evacuation of more than 3...
# 2                                                  10
# 3   destroyed 30 structures south and west of los ...
# 4   nearly 1 , 400 homes were destroyed in the bas...
# 5   destroyed at least nine homes and is blazing o...
# 6   destroying two homes in marfa and 25 structure...
# 7                          now covers 100 , 000 acres
# 8                                     No answer found
# 9   tens of thousands of acres of forest near the ...
# 10                                    No answer found
# 11  spread quickly due to the firefighters ' slow ...
# 12  destroyed 10 to 12 homes and left more than 7 ...
# 13        the number of homes lost reached almost 800
# 14                                    No answer found
# 15  perhaps an acre that saturday , the forest ser...
# 16                                               many

# %%
nb_sentences = 9
df_location = add_QA_cause_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   Texas Wildfires: 852 Homes Lost in 48 Hours - ...
# 1   Arizona Wildfire Pictures: Blaze Advancing on ...
# 2   Wild Facts About the Huge Arizona Wildfire | L...
# 3   New Mexico Wildfire Forces Los Alamos Lab to C...
# 4   Perry a No-Show at Texas Wildfire Press Confer...
# 5           Nuns Fight Washington Wildfire - ABC News
# 6                     Wildfire spared lucky residents
# 7   Smoke from Minnesota wildfire reaches Illinois...
# 8   Gov. Rick Perry sees Texas wildfires as statew...
# 9   Fire and punishment: Penalties for starting bi...
# 10    2 firefighters killed battling Florida wildfire
# 11   Israeli tourist: Wildfire in Chile not my fault
# 11  [Israeli tourist Rotem Singer, 23, suspected o...
# 12  [Dry and windy conditions spark devastating wi...
# 13  [Reed Griffith, of Montgomery Fire Rescue, hel...
# 14  [McCain said illegal aliens light fires to div...
# 15  [From her orchards on the flanks of Mount Hood...
# 16  [More than half of the homeowner insurance cla...
#
#                                              Location  \
# 0   [Texas, South Carolina, California, Bastrop Co...
# 1          [U.S., Luna, New Mexico, Arizona, Phoenix]
# 2   [Arizona, Manhattan, New York City, Greenlee C...
# 3                   [America, Los Alamos, New Mexico]
# 4   [Bastrop County, Austin, Texas, Perry, New Ham...
# 5                               [Washington, Seattle]
# 6   [Fort Davis, Presidio County, Texas, Rock Hous...
# 7   [Minnesota, Illinois, Wisconsin, Fall Lake, Mi...
# 8   [Texas, US, Perry, North Carolina, California,...
# 9   [U.S., Arizona, Texas, Highway, Oak Creek Canyon]
# 10  [Fla., Jasper, Florida, Hamilton County, Georg...
# 11                                  [Chile, Santiago]
# 12  [Texas, Oklahoma, Oklahoma City, Fort Worth, P...
# 13  [Waller County, Montgomery County, Magnolia, B...
# 14              [Arizona, the Arizona Republic, N.M.]
# 15  [Ore., Alaska, Segovia, Bambe, Portland, Washi...
# 16                                      [U.S., Texas]
#
#                                           QA_location  \
# 0                                 just east of austin
# 1                                   luna , new mexico
# 2                   apache sitgreaves national forest
# 3                                          los alamos
# 4   austin . by kate galbraith and jay root sept ....
# 5                                              golden
# 6                                     presidio county
# 7   boundary waters canoe area wilderness near fal...
# 8                                     No answer found
# 9                                 near wupatki trails
# 10                hamilton county on the georgia line
# 11     chile patagonia national park torres del paine
# 12                                      oklahoma city
# 13             south of todd mission in waller county
# 14                                            arizona
# 15                                         mount hood
# 16                                    bastrop complex
#
#                                             QA_impact  \
# 0   burned at least 600 homes and blackened 30 , 0...
# 1   the blaze forced the evacuation of more than 3...
# 2                                                  10
# 3   destroyed 30 structures south and west of los ...
# 4   nearly 1 , 400 homes were destroyed in the bas...
# 5   destroyed at least nine homes and is blazing o...
# 6   destroying two homes in marfa and 25 structure...
# 7                          now covers 100 , 000 acres
# 8                                     No answer found
# 9   tens of thousands of acres of forest near the ...
# 10                                    No answer found
# 11  spread quickly due to the firefighters ' slow ...
# 12  destroyed 10 to 12 homes and left more than 7 ...
# 13        the number of homes lost reached almost 800
# 14                                    No answer found
# 15  perhaps an acre that saturday , the forest ser...
# 16                                               many
#
#                                              QA_cause
# 0                                             drought
# 1            blackens the sky above u . s . route 180
# 2   illegal immigrants attempting to hide from bor...
# 3   scientists once conducted tests on radioactive...
# 4                                               [SEP]
# 5                                     grass and brush
# 6   [SEP] fort davis with west texas roots that go...
# 7                                    lightning strike
# 8                                     No answer found
# 9                                       erratic winds
# 10                                    No answer found
# 11  firefighters ' slow response to the emergency ...
# 12                           dry and windy conditions
# 13  small particulate matter including smoke , soo...
# 14                                an escaped campfire
# 15                thunderstorms and lightning strikes
# 16  the heat was so intense that the foundation of...
