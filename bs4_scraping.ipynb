# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# #soup.find() ne trouve que le premier tag dans l'html, pour tous les avoir, il faut utiliser soup.find_all()
#
# #En utilisant les méthodes find et find all on peut spécifier le type de balise que l'on cherche ainsi que leur classe html

# %%
MY_LINKS = [
"https://www.nifc.gov/fire-information/nfn",
"https://www.nbcnews.com/western-wildfires",
"https://wildfiretoday.com/",
"https://www.hcn.org/issues/53.11/south-wildfire-hmong-americans-in-northern-california-fight-wildfire-and-distrust",
"https://www.reddit.com/r/wildfires/",
"https://en.wikipedia.org/wiki/Wildfires_in_2020",
]

# %%
#WIKIPEDIA

#requests.get renvoie la réponse de la page, pour avoir le contenu, il faut utiliser text, ainsi on peut en faire une soup
html_text = requests.get(MY_LINKS[5]).text

soup = BeautifulSoup(html_text, 'lxml')

#getting div with "main" id
html_main_div = soup.find('div', {"id" : "mw-content-text"})

table = html_main_div.find_all('table')
df = pd.read_html(str(table))[3]

df
# Out:
#          Coordination Center       Acres   Hectares  Suppression Costs  \
# 0         Alaska Interagency    171045.7    69219.7     $14,837,241.00
# 1             Northwest Area   1925434.2   779195.6    $334,672,820.78
# 2   Northern California Area   3961089.6  1602996.1  $1,369,875,556.25
# 3   Southern California Area   1241246.5   502314.6    $751,084,644.00
# 4           Northern Rockies    359948.6   145666.0     $71,770,047.00
# 5                Great Basin    891689.5   360853.9    $236,649,112.00
# 6             Southwest Area   1036287.6   419370.7    $192,069,000.96
# 7        Rocky Mountain Area    818608.6   331279.1    $276,080,314.34
# 8               Eastern Area     10508.4     4252.6        $522,398.58
# 9              Southern Area   2678366.3  1083896.4     $14,692,891.11
# 10                 Totals[a]  13094224.9  5299044.8  $3,262,254,026.02
#
#     Structures Destroyed
# 0                      8
# 1                   4473
# 2                   7410
# 3                   1824
# 4                    222
# 5                    172
# 6                     63
# 7                    212
# 8                     19
# 9                    313
# 10                 14716

# %%
#NBC Western wildfires
html_text = requests.get(MY_LINKS[1]).text

soup = BeautifulSoup(html_text, 'lxml')

#getting div with "main" id
html_main_div = soup.find('div', class_ = "rail__container layout-leftRail layout-grid-container")

html_rows = html_main_div.find_all('div', class_ = "wide-tease-item__wrapper df flex-column flex-row-m flex-nowrap-m")

for r in html_rows:
    headers = r.find_all('h2')
    title = []
    for h in headers[1:]:
        title.append(str(h.text))
    print(title)
    print(r.a['href'])

print(html_main_div.text)
# Out:
# ['Western Wildfires', 'Wildfire near Rocky Mountain National Park fully contained at 147 acres']
# https://www.nbcnews.com/news/us-news/wildfire-rocky-mountain-national-park-fully-contained-147-acres-rcna6258
# ['California Wildfires', 'Thousands of giant sequoias killed in California wildfires']
# https://www.nbcnews.com/news/california-wildfires
# ['Western Wildfires', 'Former California professor indicted on arson charges in 4 wildfires']
# https://www.nbcnews.com/news/us-news/former-california-professor-indicted-arson-charges-4-wildfires-rcna6099
# ['Western Wildfires', 'Colorado pilot fighting wildfire was making final pass before deadly crash, officials say']
# https://www.nbcnews.com/news/us-news/colorado-pilot-fighting-wildfire-was-making-final-pass-deadly-crash-of-rcna5959
# ['Western Wildfires', 'Pilot dead after air tanker crashes near Colorado wildfire']
# https://www.nbcnews.com/news/us-news/wildfire-prompts-evacuations-rocky-mountain-national-park-rcna5752
# ['Data Graphics', "Map: Track California's Alisal Fire"]
# https://www.nbcnews.com/datagraphics
# ['California Wildfires', 'California wildfire balloons to 13,400 acres, jumps major highway']
# https://www.nbcnews.com/news/california-wildfires
# ['California Wildfires', 'Ex-yoga teacher accused of arson in destructive Northern California blaze']
# https://www.nbcnews.com/news/california-wildfires
# ['NBC News NOW', 'California wildfires: Sequoias burn as state grapples with multiple blazes']
# https://www.nbcnews.com/now/video/california-wildfires-sequoias-burn-as-state-grapples-with-multiple-blazes-121940037786
# ['Climate in Crisis', 'California Gov. Newsom commits $15B to combat wildfire, drought and climate change']
# https://www.nbcnews.com/climate-in-crisis
# ['Western Wildfires', 'Free, pop-up day camp becomes a home away from home for kids displaced by wildfires']
# https://www.nbcnews.com/news/us-news/camp-kids-traumatized-natural-disasters-offers-space-healing-n1279481
# Latest storiesWestern Wildfires10d agoWestern WildfiresWildfire near Rocky Mountain National Park fully contained at 147 acresAn air tanker pilot died in a crash while trying helping to fight the Kruger Rock Fire, which broke out Tuesday after winds knocked a tree onto a power line.California Wildfires12d agoCalifornia WildfiresThousands of giant sequoias killed in California wildfiresAfter last year’s fires took officials by surprise by wiping out so many sequoias, extraordinary measures were taken to save the largest and oldest trees this year.Western Wildfires12d agoWestern WildfiresFormer California professor indicted on arson charges in 4 wildfiresGary Stephen Maynard  is accused of setting the small fires in the area of the Dixie Fire, some of which were behind firefighters battling the larger blaze.Western Wildfires13d agoWestern WildfiresColorado pilot fighting wildfire was making final pass before deadly crash, officials sayMarc Thor Olson was killed when the plane he was flying crashed while he was battling the Kruger Rock Fire.Western Wildfires14d agoWestern WildfiresPilot dead after air tanker crashes near Colorado wildfireThe air tanker crashed Tuesday night near a part of Colorado where crews have been battling the Kruger Rock Fire, which had prompted evacuations.Data Graphics49d agoData GraphicsMap: Track California's Alisal FireThe Alisal Fire has grown to cover more than 20 square miles in just two days.California Wildfires49d agoCalifornia WildfiresCalifornia wildfire balloons to 13,400 acres, jumps major highwayU.S. Highway 101, which stretches from California through Washington state, was closed near Santa Barbara.California Wildfires64d agoCalifornia WildfiresEx-yoga teacher accused of arson in destructive Northern California blazeAlexandra Souverneva, 30, has pleaded not guilty to felony arson, and her attorney has said "no evidence has been presented to the contrary."NBC News NOW67d agoNBC News NOWCalifornia wildfires: Sequoias burn as state grapples with multiple blazesWildfires across California are forcing thousands to evacuate and leaving behind a path of destruction to homes and forests. NBC New's Steve Patterson reports.Climate in Crisis69d agoClimate in CrisisCalifornia Gov. Newsom commits $15B to combat wildfire, drought and climate change“California is doubling down on our nation-leading policies to confront the climate crisis head-on while protecting the hardest-hit communities,” he said.Western Wildfires74d agoWestern WildfiresFree, pop-up day camp becomes a home away from home for kids displaced by wildfires"They show up at the beginning of the day quiet and reserved, and at the end of the day it’s actually hard to peel them away," the executive director said.Load More
