# %%
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer
from streamlit_utils import *
from datetime import datetime
#Model
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

#Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-ac174104453f> in <module>
#       2 from transformers import BertForQuestionAnswering
#       3 from transformers import BertTokenizer
# ----> 4 from streamlit_utils import *
#       5 from datetime import datetime
#       6 #Model
#
# c:\Users\thoma\Documents\CS\3A\Dominante InfoNum\Projet Illuin\Projet-Illuin\streamlit_utils.py in <module>
#      30 import numpy as np
#      31
# ---> 32 from deep_translator import GoogleTranslator
#      33 from datetime import datetime, timedelta
#      34 import parsedatetime as pdt
#
# ModuleNotFoundError: No module named 'deep_translator'

# %%
# Apply the tokenizer to the input text, treating them as a text-pair.
def tokenize_input_text(question, input_text):

    input_ids = tokenizer.encode(question, input_text)

    return input_ids

# %%
def get_segment_ids(input_ids):
    # Search the input_ids for the first instance of the `[SEP]` token.
    sep_index = input_ids.index(tokenizer.sep_token_id)

    # The number of segment A tokens includes the [SEP] token istelf.
    num_seg_a = sep_index + 1

    # The remainder are segment B.
    num_seg_b = len(input_ids) - num_seg_a

    # Construct the list of 0s and 1s.
    segment_ids = [0]*num_seg_a + [1]*num_seg_b

    # There should be a segment_id for every input token.
    assert len(segment_ids) == len(input_ids)

    return segment_ids

# %%
def get_scores(input_ids,segment_ids):
    # Run through the model.
    start_scores, end_scores = model(torch.tensor([input_ids]), # The tokens representing our input text.
                                    token_type_ids=torch.tensor([segment_ids]),
                                    return_dict = False) # The segment IDs to differentiate question from answer_text
    return start_scores, end_scores

# %%
# Find the tokens with the highest `start` and `end` scores.
def get_answer(start_scores,end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)

    # Combine the tokens in the answer and print it out.
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = ' '.join(tokens[answer_start:answer_end+1])

    return answer

# %%
# Better version

def get_answer_clean(start_scores, end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = tokens[answer_start]

    # Select the remaining answer tokens and join them with whitespace.
    for i in range(answer_start + 1, answer_end + 1):
        
        # If it's a subword token, then recombine it with the previous token.
        if tokens[i][0:2] == '##':
            answer += tokens[i][2:]
        
        # Otherwise, add a space then the token.
        else:
            answer += ' ' + tokens[i]
    return answer

# %%
def answer_from_question(question, input_text):
    input_ids = tokenize_input_text(question, input_text)
    segment_ids = get_segment_ids(input_ids)
    start_scores, end_scores = get_scores(input_ids, segment_ids)

    res = get_answer_clean(start_scores, end_scores, input_ids)

    if '[CLS]' in res:
        return "No answer found"    
    return res

# %%
def get_first_senteces_from_sentences_list(sentences_list, nb_sentences):
    return "".join(sentences_list[0:nb_sentences])

# %%
def add_QA_location_to_df(df_location, subject, nb_sentences=10):
    question = "Where did the " + subject + " occur?"
    df_location["QA_location"] = None
    df_location["QA_location"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_impact_to_df(df_location, subject, nb_sentences=10):
    question = "What were the impact of the " + subject + " ?"
    df_location["QA_impact"] = None
    df_location["QA_impact"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_cause_to_df(df_location, subject, nb_sentences=10):
    question = "What caused the " + subject + " ?"
    df_location["QA_cause"] = None
    df_location["QA_cause"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
min_date = datetime(2019,1,1)
max_date = datetime(2020,1,1)
date_limits = (min_date, max_date)
subject = "wilfire"
nb_pages = 4
df_location = get_locations_df_from_subject(subject, nb_pages, date_limits)

df_location
# Out:
# Successfully scraped :  40  links
# Done scraping
# There are 19 usable articles
#                                                 Title  \
# 0   Goats help save California's Reagan library fr...
# 1   Fact-checking Trump's California wildfire crit...
# 2   California’s wildfire blackouts are a mess. He...
# 3   Burning trash sparked wildfire that destroyed ...
# 4   California Republicans object after Trump thre...
# 5   California wildfires: tens of thousands ordere...
# 6   Kincade Fire in Sonoma County continues to rag...
# 7   California governor signs bill for $21 billion...
# 8   Christmas Eve Wildfire in Chile Destroys Dozen...
# 9   Pourquoi dit-on que le HTC Wildfire X n’est pa...
# 10  California’s Wildfires Are the Doom of Our Own...
# 11  Satellites Track California's Devastating Kinc...
# 12  California wildfires: violent winds fuel Kinca...
# 13  Explainer: California faces decade of 'unique'...
# 14  Australia sending aid to wildfire towns as dea...
# 15  Wildfire: turning up the heat on energy genera...
# 16  Potential Progress on California Wildfire Issu...
# 17  California Wildfire Fund Would Put Aside $21 B...
# 18  PG&E Reaches $13.5 Billion Deal With Wildfire ...
#
#                                                  Link        Date  \
# 0   https://www.reuters.com/article/us-california-...  2019-10-30
# 1   https://www.cnn.com/2019/11/04/politics/califo...  2019-11-04
# 2   https://www.vox.com/energy-and-environment/201...  2019-10-22
# 3   https://www.reuters.com/article/california-wil...  2019-10-11
# 4   https://www.reuters.com/article/us-california-...  2019-01-09
# 5   https://www.theguardian.com/us-news/2019/oct/2...  2019-10-24
# 6   https://www.sfgate.com/california-wildfires/ar...  2019-10-26
# 7   https://www.reuters.com/article/us-california-...  2019-07-12
# 8   https://www.nytimes.com/2019/12/25/world/ameri...  2019-12-25
# 9   https://actu.meilleurmobile.com/pourquoi-dit-o...  2019-08-24
# 10  https://www.wired.com/story/californias-wildfi...  2019-10-28
# 11  https://www.space.com/california-kincade-wildf...  2019-10-28
# 12  https://www.theguardian.com/us-news/2019/oct/2...  2019-10-29
# 13  https://www.reuters.com/article/us-california-...  2019-11-22
# 14  https://www.deseret.com/2020/1/1/21045511/aust...  2020-01-01
# 15  https://www.power-technology.com/features/wild...  2019-04-29
# 16  https://www.nrdc.org/experts/ralph-cavanagh/po...  2019-05-30
# 17  https://www.nytimes.com/2019/06/21/business/en...  2019-06-21
# 18  https://www.nytimes.com/2019/12/06/business/en...  2019-12-06
#
#                                         Clean_content  \
# 0   By Omar Younis, Andrew Hay 3 Min Read SIMI VAL...
# 1   By Tara Subramaniam  Updated 0234 GMT  Novembe...
# 2   Grid hardening, land use reform, and restructu...
# 3   By Reuters Staff 4 Min Read Oct 11    Burning ...
# 4   By Sharon Bernstein, Susan Heavey 5 Min Read S...
# 5   First published on Thu 24 Oct 2019 16.38 BST T...
# 6   Smoky conditions on Shiloh Ridge Road in Sonom...
# 7   By Jim Christie 3 Min Read SAN FRANCISCO    Ca...
# 8   Advertisement Supported by Firefighters strugg...
# 9   Partager la publication Pourquoi dit on que le...
# 10  Matt Simon To revist this article, visit My Pr...
# 11   By    Meghan Bartels    published 28 October ...
# 12  Last modified on Tue 29 Oct 2019 14.55 GMT Cal...
# 13  By Andrew Hay 5 Min Read    California utility...
# 14  Filed under: PERTH, Australia Australia deploy...
# 15  A court case to determine whether Pacific Gas ...
# 16  Photo by Carsten Schertzer/iStock A California...
# 17  Advertisement Supported by By Ivan Penn and Pe...
# 18  Advertisement Supported by The agreement could...
#
#                                             Sentences  \
# 0   [By Omar Younis, Andrew Hay 3 Min Read SIMI VA...
# 1   [By Tara Subramaniam  Updated 0234 GMT  Novemb...
# 2   [Grid hardening, land use reform, and restruct...
# 3   [By Reuters Staff 4 Min Read Oct 11    Burning...
# 4   [By Sharon Bernstein, Susan Heavey 5 Min Read ...
# 5   [First published on Thu 24 Oct 2019 16.38 BST ...
# 6   [Smoky conditions on Shiloh Ridge Road in Sono...
# 7   [By Jim Christie 3 Min Read SAN FRANCISCO    C...
# 8   [Advertisement Supported by Firefighters strug...
# 9   [Partager la publication Pourquoi dit on que l...
# 10  [Matt Simon To revist this article, visit My P...
# 11  [By    Meghan Bartels    published 28 October ...
# 12  [Last modified on Tue 29 Oct 2019 14.55 GMT Ca...
# 13  [By Andrew Hay 5 Min Read    California utilit...
# 14  [Filed under: PERTH, Australia Australia deplo...
# 15  [A court case to determine whether Pacific Gas...
# 16  [Photo by Carsten Schertzer/iStock A Californi...
# 17  [Advertisement Supported by By Ivan Penn and P...
# 18  [Advertisement Supported by The agreement coul...
#
#                                              Location
# 0   [Calif., California, Simi Valley, Los Angeles,...
# 1                            [Washington, California]
# 2   [California, San Diego County, Sonoma County, ...
# 3   [California, Riverside County, Los Angeles, Sa...
# 4   [WASHINGTON, U.S., California, San Francisco, ...
# 5   [California, Los Angeles, Santa Clarita, Santa...
# 6   [Sonoma County, Healdsburg, Santa Rosa, Calif....
# 7                         [California, San Francisco]
# 8       [Chile, Australia, Brazil, the United States]
# 9                                   [basée, modèle]
# 10               [California, Del Mar, US, Montecito]
# 11  [California, Sonoma County, Photos, New York C...
# 12  [Los Angeles, Sonoma, California, Bel Air, San...
# 13  [California, the United States, U.S., Palo Alt...
# 14  [New South Wales, Mallacoota, South Wales, Con...
# 15  [California, US, Australia, Butte County, San ...
# 16                           [California, Sacramento]
# 17                    [California, the United States]
# 18  [Sacramento, San Jose, Oakland, California, Sa...

# %%
nb_sentences = 10
df_location = add_QA_location_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   Goats help save California's Reagan library fr...
# 1   Fact-checking Trump's California wildfire crit...
# 2   California’s wildfire blackouts are a mess. He...
# 3   Burning trash sparked wildfire that destroyed ...
# 4   California Republicans object after Trump thre...
# 5   California wildfires: tens of thousands ordere...
# 6   Kincade Fire in Sonoma County continues to rag...
# 7   California governor signs bill for $21 billion...
# 8   Christmas Eve Wildfire in Chile Destroys Dozen...
# 9   Pourquoi dit-on que le HTC Wildfire X n’est pa...
# 10  California’s Wildfires Are the Doom of Our Own...
# 11  Satellites Track California's Devastating Kinc...
# 12  California wildfires: violent winds fuel Kinca...
# 13  Explainer: California faces decade of 'unique'...
# 14  Australia sending aid to wildfire towns as dea...
# 15  Wildfire: turning up the heat on energy genera...
# 16  Potential Progress on California Wildfire Issu...
# 17  California Wildfire Fund Would Put Aside $21 B...
# 18  PG&E Reaches $13.5 Billion Deal With Wildfire ...
#
#                                                  Link        Date  \
# 0   https://www.reuters.com/article/us-california-...  2019-10-30
# 1   https://www.cnn.com/2019/11/04/politics/califo...  2019-11-04
# 2   https://www.vox.com/energy-and-environment/201...  2019-10-22
# 3   https://www.reuters.com/article/california-wil...  2019-10-11
# 4   https://www.reuters.com/article/us-california-...  2019-01-09
# 5   https://www.theguardian.com/us-news/2019/oct/2...  2019-10-24
# 6   https://www.sfgate.com/california-wildfires/ar...  2019-10-26
# 7   https://www.reuters.com/article/us-california-...  2019-07-12
# 8   https://www.nytimes.com/2019/12/25/world/ameri...  2019-12-25
# 9   https://actu.meilleurmobile.com/pourquoi-dit-o...  2019-08-24
# 10  https://www.wired.com/story/californias-wildfi...  2019-10-28
# 11  https://www.space.com/california-kincade-wildf...  2019-10-28
# 12  https://www.theguardian.com/us-news/2019/oct/2...  2019-10-29
# 13  https://www.reuters.com/article/us-california-...  2019-11-22
# 14  https://www.deseret.com/2020/1/1/21045511/aust...  2020-01-01
# 15  https://www.power-technology.com/features/wild...  2019-04-29
# 16  https://www.nrdc.org/experts/ralph-cavanagh/po...  2019-05-30
# 17  https://www.nytimes.com/2019/06/21/business/en...  2019-06-21
# 18  https://www.nytimes.com/2019/12/06/business/en...  2019-12-06
#
#                                         Clean_content  \
# 0   By Omar Younis, Andrew Hay 3 Min Read SIMI VAL...
# 1   By Tara Subramaniam  Updated 0234 GMT  Novembe...
# 2   Grid hardening, land use reform, and restructu...
# 3   By Reuters Staff 4 Min Read Oct 11    Burning ...
# 4   By Sharon Bernstein, Susan Heavey 5 Min Read S...
# 5   First published on Thu 24 Oct 2019 16.38 BST T...
# 6   Smoky conditions on Shiloh Ridge Road in Sonom...
# 7   By Jim Christie 3 Min Read SAN FRANCISCO    Ca...
# 8   Advertisement Supported by Firefighters strugg...
# 9   Partager la publication Pourquoi dit on que le...
# 10  Matt Simon To revist this article, visit My Pr...
# 11   By    Meghan Bartels    published 28 October ...
# 12  Last modified on Tue 29 Oct 2019 14.55 GMT Cal...
# 13  By Andrew Hay 5 Min Read    California utility...
# 14  Filed under: PERTH, Australia Australia deploy...
# 15  A court case to determine whether Pacific Gas ...
# 16  Photo by Carsten Schertzer/iStock A California...
# 17  Advertisement Supported by By Ivan Penn and Pe...
# 18  Advertisement Supported by The agreement could...
#
#                                             Sentences  \
# 0   [By Omar Younis, Andrew Hay 3 Min Read SIMI VA...
# 1   [By Tara Subramaniam  Updated 0234 GMT  Novemb...
# 2   [Grid hardening, land use reform, and restruct...
# 3   [By Reuters Staff 4 Min Read Oct 11    Burning...
# 4   [By Sharon Bernstein, Susan Heavey 5 Min Read ...
# 5   [First published on Thu 24 Oct 2019 16.38 BST ...
# 6   [Smoky conditions on Shiloh Ridge Road in Sono...
# 7   [By Jim Christie 3 Min Read SAN FRANCISCO    C...
# 8   [Advertisement Supported by Firefighters strug...
# 9   [Partager la publication Pourquoi dit on que l...
# 10  [Matt Simon To revist this article, visit My P...
# 11  [By    Meghan Bartels    published 28 October ...
# 12  [Last modified on Tue 29 Oct 2019 14.55 GMT Ca...
# 13  [By Andrew Hay 5 Min Read    California utilit...
# 14  [Filed under: PERTH, Australia Australia deplo...
# 15  [A court case to determine whether Pacific Gas...
# 16  [Photo by Carsten Schertzer/iStock A Californi...
# 17  [Advertisement Supported by By Ivan Penn and P...
# 18  [Advertisement Supported by The agreement coul...
#
#                                              Location  \
# 0   [Calif., California, Simi Valley, Los Angeles,...
# 1                            [Washington, California]
# 2   [California, San Diego County, Sonoma County, ...
# 3   [California, Riverside County, Los Angeles, Sa...
# 4   [WASHINGTON, U.S., California, San Francisco, ...
# 5   [California, Los Angeles, Santa Clarita, Santa...
# 6   [Sonoma County, Healdsburg, Santa Rosa, Calif....
# 7                         [California, San Francisco]
# 8       [Chile, Australia, Brazil, the United States]
# 9                                   [basée, modèle]
# 10               [California, Del Mar, US, Montecito]
# 11  [California, Sonoma County, Photos, New York C...
# 12  [Los Angeles, Sonoma, California, Bel Air, San...
# 13  [California, the United States, U.S., Palo Alt...
# 14  [New South Wales, Mallacoota, South Wales, Con...
# 15  [California, US, Australia, Butte County, San ...
# 16                           [California, Sacramento]
# 17                    [California, the United States]
# 18  [Sacramento, San Jose, Oakland, California, Sa...
#
#                                           QA_location
# 0                california ’ s ronald reagan library
# 1                                          california
# 2                                          california
# 3                                            calimesa
# 4                             sacramento / washington
# 5                                               north
# 6                                     No answer found
# 7                                            paradise
# 8   santiago , chile a wildfire raged through a re...
# 9                                     No answer found
# 10                             north of san francisco
# 11                                      sonoma county
# 12                                      sonoma county
# 13                                    No answer found
# 14                                  perth , australia
# 15  californian wildfires has forced the energy co...
# 16                                    No answer found
# 17                                           paradise
# 18                                         sacramento

# %%
nb_sentences = 10
df_location = add_QA_impact_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   Goats help save California's Reagan library fr...
# 1   Fact-checking Trump's California wildfire crit...
# 2   California’s wildfire blackouts are a mess. He...
# 3   Burning trash sparked wildfire that destroyed ...
# 4   California Republicans object after Trump thre...
# 5   California wildfires: tens of thousands ordere...
# 6   Kincade Fire in Sonoma County continues to rag...
# 7   California governor signs bill for $21 billion...
# 8   Christmas Eve Wildfire in Chile Destroys Dozen...
# 9   Pourquoi dit-on que le HTC Wildfire X n’est pa...
# 10  California’s Wildfires Are the Doom of Our Own...
# 11  Satellites Track California's Devastating Kinc...
# 12  California wildfires: violent winds fuel Kinca...
# 13  Explainer: California faces decade of 'unique'...
# 14  Australia sending aid to wildfire towns as dea...
# 15  Wildfire: turning up the heat on energy genera...
# 16  Potential Progress on California Wildfire Issu...
# 17  California Wildfire Fund Would Put Aside $21 B...
# 18  PG&E Reaches $13.5 Billion Deal With Wildfire ...
#
#                                                  Link        Date  \
# 0   https://www.reuters.com/article/us-california-...  2019-10-30
# 1   https://www.cnn.com/2019/11/04/politics/califo...  2019-11-04
# 2   https://www.vox.com/energy-and-environment/201...  2019-10-22
# 3   https://www.reuters.com/article/california-wil...  2019-10-11
# 4   https://www.reuters.com/article/us-california-...  2019-01-09
# 5   https://www.theguardian.com/us-news/2019/oct/2...  2019-10-24
# 6   https://www.sfgate.com/california-wildfires/ar...  2019-10-26
# 7   https://www.reuters.com/article/us-california-...  2019-07-12
# 8   https://www.nytimes.com/2019/12/25/world/ameri...  2019-12-25
# 9   https://actu.meilleurmobile.com/pourquoi-dit-o...  2019-08-24
# 10  https://www.wired.com/story/californias-wildfi...  2019-10-28
# 11  https://www.space.com/california-kincade-wildf...  2019-10-28
# 12  https://www.theguardian.com/us-news/2019/oct/2...  2019-10-29
# 13  https://www.reuters.com/article/us-california-...  2019-11-22
# 14  https://www.deseret.com/2020/1/1/21045511/aust...  2020-01-01
# 15  https://www.power-technology.com/features/wild...  2019-04-29
# 16  https://www.nrdc.org/experts/ralph-cavanagh/po...  2019-05-30
# 17  https://www.nytimes.com/2019/06/21/business/en...  2019-06-21
# 18  https://www.nytimes.com/2019/12/06/business/en...  2019-12-06
#
#                                         Clean_content  \
# 0   By Omar Younis, Andrew Hay 3 Min Read SIMI VAL...
# 1   By Tara Subramaniam  Updated 0234 GMT  Novembe...
# 2   Grid hardening, land use reform, and restructu...
# 3   By Reuters Staff 4 Min Read Oct 11    Burning ...
# 4   By Sharon Bernstein, Susan Heavey 5 Min Read S...
# 5   First published on Thu 24 Oct 2019 16.38 BST T...
# 6   Smoky conditions on Shiloh Ridge Road in Sonom...
# 7   By Jim Christie 3 Min Read SAN FRANCISCO    Ca...
# 8   Advertisement Supported by Firefighters strugg...
# 9   Partager la publication Pourquoi dit on que le...
# 10  Matt Simon To revist this article, visit My Pr...
# 11   By    Meghan Bartels    published 28 October ...
# 12  Last modified on Tue 29 Oct 2019 14.55 GMT Cal...
# 13  By Andrew Hay 5 Min Read    California utility...
# 14  Filed under: PERTH, Australia Australia deploy...
# 15  A court case to determine whether Pacific Gas ...
# 16  Photo by Carsten Schertzer/iStock A California...
# 17  Advertisement Supported by By Ivan Penn and Pe...
# 18  Advertisement Supported by The agreement could...
#
#                                             Sentences  \
# 0   [By Omar Younis, Andrew Hay 3 Min Read SIMI VA...
# 1   [By Tara Subramaniam  Updated 0234 GMT  Novemb...
# 2   [Grid hardening, land use reform, and restruct...
# 3   [By Reuters Staff 4 Min Read Oct 11    Burning...
# 4   [By Sharon Bernstein, Susan Heavey 5 Min Read ...
# 5   [First published on Thu 24 Oct 2019 16.38 BST ...
# 6   [Smoky conditions on Shiloh Ridge Road in Sono...
# 7   [By Jim Christie 3 Min Read SAN FRANCISCO    C...
# 8   [Advertisement Supported by Firefighters strug...
# 9   [Partager la publication Pourquoi dit on que l...
# 10  [Matt Simon To revist this article, visit My P...
# 11  [By    Meghan Bartels    published 28 October ...
# 12  [Last modified on Tue 29 Oct 2019 14.55 GMT Ca...
# 13  [By Andrew Hay 5 Min Read    California utilit...
# 14  [Filed under: PERTH, Australia Australia deplo...
# 15  [A court case to determine whether Pacific Gas...
# 16  [Photo by Carsten Schertzer/iStock A Californi...
# 17  [Advertisement Supported by By Ivan Penn and P...
# 18  [Advertisement Supported by The agreement coul...
#
#                                              Location  \
# 0   [Calif., California, Simi Valley, Los Angeles,...
# 1                            [Washington, California]
# 2   [California, San Diego County, Sonoma County, ...
# 3   [California, Riverside County, Los Angeles, Sa...
# 4   [WASHINGTON, U.S., California, San Francisco, ...
# 5   [California, Los Angeles, Santa Clarita, Santa...
# 6   [Sonoma County, Healdsburg, Santa Rosa, Calif....
# 7                         [California, San Francisco]
# 8       [Chile, Australia, Brazil, the United States]
# 9                                   [basée, modèle]
# 10               [California, Del Mar, US, Montecito]
# 11  [California, Sonoma County, Photos, New York C...
# 12  [Los Angeles, Sonoma, California, Bel Air, San...
# 13  [California, the United States, U.S., Palo Alt...
# 14  [New South Wales, Mallacoota, South Wales, Con...
# 15  [California, US, Australia, Butte County, San ...
# 16                           [California, Sacramento]
# 17                    [California, the United States]
# 18  [Sacramento, San Jose, Oakland, California, Sa...
#
#                                           QA_location  \
# 0                california ’ s ronald reagan library
# 1                                          california
# 2                                          california
# 3                                            calimesa
# 4                             sacramento / washington
# 5                                               north
# 6                                     No answer found
# 7                                            paradise
# 8   santiago , chile a wildfire raged through a re...
# 9                                     No answer found
# 10                             north of san francisco
# 11                                      sonoma county
# 12                                      sonoma county
# 13                                    No answer found
# 14                                  perth , australia
# 15  californian wildfires has forced the energy co...
# 16                                    No answer found
# 17                                           paradise
# 18                                         sacramento
#
#                                             QA_impact
# 0                                     No answer found
# 1                as wildfires swept across california
# 2   hundreds of thousands of its residents are reg...
# 3   destroyed dozens of homes in california ’ s ri...
# 4                                     No answer found
# 5   no injuries were immediately reported , and th...
# 6                                     No answer found
# 7   killed more than 80 people and destroyed the t...
# 8         destroying more than 200 homes by wednesday
# 9                                     No answer found
# 10                           destroyed 282 structures
# 11                            destroyed 94 structures
# 12                 destroyed more than 120 structures
# 13                                    No answer found
# 14  at least 17 people dead nationwide and sent th...
# 15  85 people lost their lives and 14 , 000 homes ...
# 16  agonizing recent memories and a continuing thr...
# 17  killed dozens of people and destroyed the town...
# 18  killed dozens of people and destroyed tens of ...

# %%
nb_sentences = 10
df_location = add_QA_cause_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   Goats help save California's Reagan library fr...
# 1   Fact-checking Trump's California wildfire crit...
# 2   California’s wildfire blackouts are a mess. He...
# 3   Burning trash sparked wildfire that destroyed ...
# 4   California Republicans object after Trump thre...
# 5   California wildfires: tens of thousands ordere...
# 6   Kincade Fire in Sonoma County continues to rag...
# 7   California governor signs bill for $21 billion...
# 8   Christmas Eve Wildfire in Chile Destroys Dozen...
# 9   Pourquoi dit-on que le HTC Wildfire X n’est pa...
# 10  California’s Wildfires Are the Doom of Our Own...
# 11  Satellites Track California's Devastating Kinc...
# 12  California wildfires: violent winds fuel Kinca...
# 13  Explainer: California faces decade of 'unique'...
# 14  Australia sending aid to wildfire towns as dea...
# 15  Wildfire: turning up the heat on energy genera...
# 16  Potential Progress on California Wildfire Issu...
# 17  California Wildfire Fund Would Put Aside $21 B...
# 18  PG&E Reaches $13.5 Billion Deal With Wildfire ...
#
#                                                  Link        Date  \
# 0   https://www.reuters.com/article/us-california-...  2019-10-30
# 1   https://www.cnn.com/2019/11/04/politics/califo...  2019-11-04
# 2   https://www.vox.com/energy-and-environment/201...  2019-10-22
# 3   https://www.reuters.com/article/california-wil...  2019-10-11
# 4   https://www.reuters.com/article/us-california-...  2019-01-09
# 5   https://www.theguardian.com/us-news/2019/oct/2...  2019-10-24
# 6   https://www.sfgate.com/california-wildfires/ar...  2019-10-26
# 7   https://www.reuters.com/article/us-california-...  2019-07-12
# 8   https://www.nytimes.com/2019/12/25/world/ameri...  2019-12-25
# 9   https://actu.meilleurmobile.com/pourquoi-dit-o...  2019-08-24
# 10  https://www.wired.com/story/californias-wildfi...  2019-10-28
# 11  https://www.space.com/california-kincade-wildf...  2019-10-28
# 12  https://www.theguardian.com/us-news/2019/oct/2...  2019-10-29
# 13  https://www.reuters.com/article/us-california-...  2019-11-22
# 14  https://www.deseret.com/2020/1/1/21045511/aust...  2020-01-01
# 15  https://www.power-technology.com/features/wild...  2019-04-29
# 16  https://www.nrdc.org/experts/ralph-cavanagh/po...  2019-05-30
# 17  https://www.nytimes.com/2019/06/21/business/en...  2019-06-21
# 18  https://www.nytimes.com/2019/12/06/business/en...  2019-12-06
#
#                                         Clean_content  \
# 0   By Omar Younis, Andrew Hay 3 Min Read SIMI VAL...
# 1   By Tara Subramaniam  Updated 0234 GMT  Novembe...
# 2   Grid hardening, land use reform, and restructu...
# 3   By Reuters Staff 4 Min Read Oct 11    Burning ...
# 4   By Sharon Bernstein, Susan Heavey 5 Min Read S...
# 5   First published on Thu 24 Oct 2019 16.38 BST T...
# 6   Smoky conditions on Shiloh Ridge Road in Sonom...
# 7   By Jim Christie 3 Min Read SAN FRANCISCO    Ca...
# 8   Advertisement Supported by Firefighters strugg...
# 9   Partager la publication Pourquoi dit on que le...
# 10  Matt Simon To revist this article, visit My Pr...
# 11   By    Meghan Bartels    published 28 October ...
# 12  Last modified on Tue 29 Oct 2019 14.55 GMT Cal...
# 13  By Andrew Hay 5 Min Read    California utility...
# 14  Filed under: PERTH, Australia Australia deploy...
# 15  A court case to determine whether Pacific Gas ...
# 16  Photo by Carsten Schertzer/iStock A California...
# 17  Advertisement Supported by By Ivan Penn and Pe...
# 18  Advertisement Supported by The agreement could...
#
#                                             Sentences  \
# 0   [By Omar Younis, Andrew Hay 3 Min Read SIMI VA...
# 1   [By Tara Subramaniam  Updated 0234 GMT  Novemb...
# 2   [Grid hardening, land use reform, and restruct...
# 3   [By Reuters Staff 4 Min Read Oct 11    Burning...
# 4   [By Sharon Bernstein, Susan Heavey 5 Min Read ...
# 5   [First published on Thu 24 Oct 2019 16.38 BST ...
# 6   [Smoky conditions on Shiloh Ridge Road in Sono...
# 7   [By Jim Christie 3 Min Read SAN FRANCISCO    C...
# 8   [Advertisement Supported by Firefighters strug...
# 9   [Partager la publication Pourquoi dit on que l...
# 10  [Matt Simon To revist this article, visit My P...
# 11  [By    Meghan Bartels    published 28 October ...
# 12  [Last modified on Tue 29 Oct 2019 14.55 GMT Ca...
# 13  [By Andrew Hay 5 Min Read    California utilit...
# 14  [Filed under: PERTH, Australia Australia deplo...
# 15  [A court case to determine whether Pacific Gas...
# 16  [Photo by Carsten Schertzer/iStock A Californi...
# 17  [Advertisement Supported by By Ivan Penn and P...
# 18  [Advertisement Supported by The agreement coul...
#
#                                              Location  \
# 0   [Calif., California, Simi Valley, Los Angeles,...
# 1                            [Washington, California]
# 2   [California, San Diego County, Sonoma County, ...
# 3   [California, Riverside County, Los Angeles, Sa...
# 4   [WASHINGTON, U.S., California, San Francisco, ...
# 5   [California, Los Angeles, Santa Clarita, Santa...
# 6   [Sonoma County, Healdsburg, Santa Rosa, Calif....
# 7                         [California, San Francisco]
# 8       [Chile, Australia, Brazil, the United States]
# 9                                   [basée, modèle]
# 10               [California, Del Mar, US, Montecito]
# 11  [California, Sonoma County, Photos, New York C...
# 12  [Los Angeles, Sonoma, California, Bel Air, San...
# 13  [California, the United States, U.S., Palo Alt...
# 14  [New South Wales, Mallacoota, South Wales, Con...
# 15  [California, US, Australia, Butte County, San ...
# 16                           [California, Sacramento]
# 17                    [California, the United States]
# 18  [Sacramento, San Jose, Oakland, California, Sa...
#
#                                           QA_location  \
# 0                california ’ s ronald reagan library
# 1                                          california
# 2                                          california
# 3                                            calimesa
# 4                             sacramento / washington
# 5                                               north
# 6                                     No answer found
# 7                                            paradise
# 8   santiago , chile a wildfire raged through a re...
# 9                                     No answer found
# 10                             north of san francisco
# 11                                      sonoma county
# 12                                      sonoma county
# 13                                    No answer found
# 14                                  perth , australia
# 15  californian wildfires has forced the energy co...
# 16                                    No answer found
# 17                                           paradise
# 18                                         sacramento
#
#                                             QA_impact  \
# 0                                     No answer found
# 1                as wildfires swept across california
# 2   hundreds of thousands of its residents are reg...
# 3   destroyed dozens of homes in california ’ s ri...
# 4                                     No answer found
# 5   no injuries were immediately reported , and th...
# 6                                     No answer found
# 7   killed more than 80 people and destroyed the t...
# 8         destroying more than 200 homes by wednesday
# 9                                     No answer found
# 10                           destroyed 282 structures
# 11                            destroyed 94 structures
# 12                 destroyed more than 120 structures
# 13                                    No answer found
# 14  at least 17 people dead nationwide and sent th...
# 15  85 people lost their lives and 14 , 000 homes ...
# 16  agonizing recent memories and a continuing thr...
# 17  killed dozens of people and destroyed the town...
# 18  killed dozens of people and destroyed tens of ...
#
#                                    QA_cause
# 0                          gale force winds
# 1         wildfires swept across california
# 2                            global warming
# 3   burning trash dumped by a garbage truck
# 4                    poor forest management
# 5                       dry , windy weather
# 6                            powerful winds
# 7              failures of pg & e equipment
# 8                            climate change
# 9                           No answer found
# 10                       100 mph wind gusts
# 11                               high winds
# 12                                  violent
# 13                     power infrastructure
# 14                          No answer found
# 15     networks transitioning to renewables
# 16                       climate disruption
# 17     equipment that brings power to homes
# 18                          No answer found

# %%
import re

def classification_CI(CI, isI):
    if isI:
        list_HI = ["people", "killed", "resident", "residents"]
        list_MI = ["structure", "structures", "homes", "cost"]
        cost = "[0-9\.]*\$"
        list_SI = ["km2", "km²", "a", "ha", "sq. Yd."]
        detected_I = [False, False, False]
        for word in CI.split():
            if word.lower() in list_HI:
                detected_I[0] = True
            if word.lower() in list_MI or re.search(cost, word) != None:
                detected_I[1] = True
            if word.lower() in list_SI:
                detected_I[2] = True
        return detected_I
    
    else:
        list_HC = ["people", "infrastructure", "equipment", "butt", "management", "trash"]
        list_CC = ["wind", "winds", "dry", "windy", "earthquake"]
        list_OC = ["global", "warming", "climate", "change"]
        detected_C = [False, False, False]
        for word in CI.split():
            if word.lower() in list_HC:
                detected_C[0] = True
            if word.lower() in list_CC:
                detected_C[1] = True
            if word.lower() in list_OC:
                detected_C[2] = True
        if not detected_C[0] and not detected_C[1] and not detected_C[2]:
            detected_C[2] = True
        return detected_C

def comprehension(list, isI):
    if isI:
        if list[0]:
            print("Impact humain")
        if list[1]:
            print("Impact matériel")
        if list[2]:
            print("Impact surfacique")
        if not list[0] and not list[1] and not list[2]:
            print("Impact inconnu ou aucun impact")

    else:
        if list[0]:
            print("Cause humaine")
        if list[1]:
            print("Conséquence d'une autre catastrophe ou d'un événement naturel ponctuel")
        if list[2]:
            print("Cause globale ou inconnue")

for impact in df_location["QA_impact"]:
    print(impact)
    comprehension(classification_CI(impact, True), True)

for cause in df_location["QA_cause"]:
    print(cause)
    comprehension(classification_CI(cause, False), False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a60b647c8a1> in <module>
#      52             print("Cause globale ou inconnue")
#      53
# ---> 54 for impact in df_location["QA_impact"]:
#      55     print(impact)
#      56     comprehension(classification_CI(impact, True), True)
#
# NameError: name 'df_location' is not defined
