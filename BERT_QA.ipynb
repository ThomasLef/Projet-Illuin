# %%
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer
from streamlit_utils import *
from datetime import datetime
#Model
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

#Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
# Apply the tokenizer to the input text, treating them as a text-pair.
def tokenize_input_text(question, input_text):

    input_ids = tokenizer.encode(question, input_text)

    return input_ids

# %%
def get_segment_ids(input_ids):
    # Search the input_ids for the first instance of the `[SEP]` token.
    sep_index = input_ids.index(tokenizer.sep_token_id)

    # The number of segment A tokens includes the [SEP] token istelf.
    num_seg_a = sep_index + 1

    # The remainder are segment B.
    num_seg_b = len(input_ids) - num_seg_a

    # Construct the list of 0s and 1s.
    segment_ids = [0]*num_seg_a + [1]*num_seg_b

    # There should be a segment_id for every input token.
    assert len(segment_ids) == len(input_ids)

    return segment_ids

# %%
def get_scores(input_ids,segment_ids):
    # Run through the model.
    start_scores, end_scores = model(torch.tensor([input_ids]), # The tokens representing our input text.
                                    token_type_ids=torch.tensor([segment_ids]),
                                    return_dict = False) # The segment IDs to differentiate question from answer_text
    return start_scores, end_scores

# %%
# Find the tokens with the highest `start` and `end` scores.
def get_answer(start_scores,end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)

    # Combine the tokens in the answer and print it out.
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = ' '.join(tokens[answer_start:answer_end+1])

    return answer

# %%
# Better version

def get_answer_clean(start_scores, end_scores, input_ids):
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    answer = tokens[answer_start]

    # Select the remaining answer tokens and join them with whitespace.
    for i in range(answer_start + 1, answer_end + 1):
        
        # If it's a subword token, then recombine it with the previous token.
        if tokens[i][0:2] == '##':
            answer += tokens[i][2:]
        
        # Otherwise, add a space then the token.
        else:
            answer += ' ' + tokens[i]
    return answer

# %%
def answer_from_question(question, input_text):
    input_ids = tokenize_input_text(question, input_text)
    segment_ids = get_segment_ids(input_ids)
    start_scores, end_scores = get_scores(input_ids, segment_ids)

    res = get_answer_clean(start_scores, end_scores, input_ids)

    if '[CLS]' in res:
        return "No answer found"    
    return res

# %%
def get_first_senteces_from_sentences_list(sentences_list, nb_sentences):
    return "".join(sentences_list[0:nb_sentences])

# %%
def add_QA_location_to_df(df_location, subject, nb_sentences=9):
    question = "Where did the " + subject + " occur?"
    df_location["QA_location"] = None
    df_location["QA_location"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_impact_to_df(df_location, subject, nb_sentences=10):
    question = "What were the impact of the " + subject + " ?"
    df_location["QA_impact"] = None
    df_location["QA_impact"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
def add_QA_cause_to_df(df_location, subject, nb_sentences=10):
    question = "What caused the " + subject + " ?"
    df_location["QA_cause"] = None
    df_location["QA_cause"] = df_location["Sentences"].apply(lambda x : answer_from_question(question, get_first_senteces_from_sentences_list(x,nb_sentences)))
    return df_location

# %%
min_date = datetime(2011,1,1)
max_date = datetime(2012,1,1)
date_limits = (min_date, max_date)
subject = "tsunami"
nb_pages = 4
df_location = get_locations_df_from_subject(subject, nb_pages, date_limits)

df_location
# Out:
# Successfully scraped :  40  links
# Done scraping
# There are 15 usable articles
#                                                 Title  \
# 0   California harbor 'destroyed' by tsunami, but ...
# 1   Tsunami Causes Heavy Damage to Crescent City H...
# 2   Tsunamis in the United States have hit Crescen...
# 3   Hawaii County surveys tsunami damage, Kona hit...
# 4   Gillard sees tsunami devastation first hand - ...
# 5   Hawaii says tsunami damage cost $30.6 million,...
# 6   \n    Proposed GOP budget cuts target tsunami ...
# 7    Midway's Albatrosses Survive the Tsunami | WIRED
# 8   Crescent City, Calif., Recovers From Its Own T...
# 9   Oregon Coast tsunami: Serious damage reports f...
# 10  On Stones in Japan, Tsunami Warnings — Aneyosh...
# 11  Search Suspended for California Man Swept Into...
# 12  Tracking the Destructive Power of the Pacific ...
# 13  Tsunami Debris to Hit U.S. Sooner Than Expecte...
# 14  Man swept out to sea by tsunami was Bend nativ...
#
#                                                  Link        Date  \
# 0   https://www.csmonitor.com/USA/2011/0311/Califo...  2011-03-11
# 1   https://www.nbcbayarea.com/news/local/tsunami-...  2011-03-11
# 2   https://slate.com/news-and-politics/2011/03/ts...  2011-03-11
# 3   https://www.bigislandvideonews.com/2011/03/11/...  2011-03-11
# 4   https://www.abc.net.au/news/2011-04-23/gillard...  2011-04-22
# 5   https://www.bigislandvideonews.com/2011/03/24/...  2011-03-24
# 6   https://www.cbsnews.com/news/proposed-gop-budg...  2011-03-11
# 7   https://www.wired.com/2011/03/albatrosses-tsun...  2011-03-15
# 8   https://www.nytimes.com/2011/03/17/us/17cresce...  2011-03-16
# 9   https://www.oregonlive.com/pacific-northwest-n...  2011-03-11
# 10  https://www.nytimes.com/2011/04/21/world/asia/...  2011-04-20
# 11  https://abcnews.go.com/US/california-man-swept...  2011-03-11
# 12  https://e360.yale.edu/features/tracking_the_de...  2011-03-22
# 13  http://abcnews.go.com/blogs/technology/2011/10...  2011-10-25
# 14  https://www.oregonlive.com/pacific-northwest-n...  2011-03-13
#
#                                         Clean_content  \
# 0   Loading...  March 11, 2011 The tsunami waves u...
# 1   The power of an 8.9 earthquake in Japan genera...
# 2   The tsunami capital of the continental United ...
# 3   Media release | Hawaii County Office of the Ma...
# 4   Prime Minister Julia Gillard has visited a coa...
# 5   Media release | Hawaii Office of the Governor ...
# 6              By Lucy Madison           March 11,...
# 7   Brandon Keim To revist this article, visit My ...
# 8   Advertisement Supported by Crescent City Journ...
# 9   Reports of serious damage are coming from the ...
# 10  Advertisement Supported by Aneyoshi Journal By...
# 11  California docks take a beating and boats smas...
# 12  The devastating tsunami in northeastern Japan ...
# 13  ABC News  The devastating tsunami that hit Jap...
# 14  Leaving his teenage drug abuse behind in Orego...
#
#                                             Sentences  \
# 0   [Loading...  March 11, 2011 The tsunami waves ...
# 1   [The power of an 8.9 earthquake in Japan gener...
# 2   [The tsunami capital of the continental United...
# 3   [Media release | Hawaii County Office of the M...
# 4   [Prime Minister Julia Gillard has visited a co...
# 5   [Media release | Hawaii Office of the Governor...
# 6   [By Lucy Madison           March 11, 2011 / 4:...
# 7   [Brandon Keim To revist this article, visit My...
# 8   [Advertisement Supported by Crescent City Jour...
# 9   [Reports of serious damage are coming from the...
# 10  [Advertisement Supported by Aneyoshi Journal B...
# 11  [California docks take a beating and boats sma...
# 12  [The devastating tsunami in northeastern Japan...
# 13  [ABC News  The devastating tsunami that hit Ja...
# 14  [Leaving his teenage drug abuse behind in Oreg...
#
#                                              Location
# 0   [Japan, America, Crescent City, Calif., Oregon...
# 1   [Japan, California, Santa Cruz, Crescent City,...
# 2   [United States, Crescent City, Calif., Oregon,...
# 3   [the Hawaiian Islands, the County of, Japan, W...
# 4   [Japan, Minami Sanriku, Australia, Sydney, Min...
# 5   [Honolulu, Hawaii Island, the Big Island, Hawa...
# 6                                     [Japan, Hawaii]
# 7              [Honolulu, Tokyo, U.S., Alaska, Leary]
# 8   [CRESCENT CITY, Calif., Crescent City, Tsunami...
# 9   [Japan, Tsunami, Oregon, Curry County, Gold Be...
# 10          [Japan, Kyoto, Jogan, Hiroshima, Morioka]
# 11  [California, Santa Cruz, Oregon, U.S., Brookin...
# 12  [Japan, United States, California, Tokyo, Hons...
# 13  [Japan, the United States, Texas, Midway Islan...
# 14   [Oregon, California, Japan, Crescent City, Bend]

# %%
nb_sentences = 9
df_location = add_QA_location_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   California harbor 'destroyed' by tsunami, but ...
# 1   Tsunami Causes Heavy Damage to Crescent City H...
# 2   Tsunamis in the United States have hit Crescen...
# 3   Hawaii County surveys tsunami damage, Kona hit...
# 4   Gillard sees tsunami devastation first hand - ...
# 5   Hawaii says tsunami damage cost $30.6 million,...
# 6   \n    Proposed GOP budget cuts target tsunami ...
# 7    Midway's Albatrosses Survive the Tsunami | WIRED
# 8   Crescent City, Calif., Recovers From Its Own T...
# 9   Oregon Coast tsunami: Serious damage reports f...
# 10  On Stones in Japan, Tsunami Warnings — Aneyosh...
# 11  Search Suspended for California Man Swept Into...
# 12  Tracking the Destructive Power of the Pacific ...
# 13  Tsunami Debris to Hit U.S. Sooner Than Expecte...
# 14  Man swept out to sea by tsunami was Bend nativ...
#
#                                                  Link        Date  \
# 0   https://www.csmonitor.com/USA/2011/0311/Califo...  2011-03-11
# 1   https://www.nbcbayarea.com/news/local/tsunami-...  2011-03-11
# 2   https://slate.com/news-and-politics/2011/03/ts...  2011-03-11
# 3   https://www.bigislandvideonews.com/2011/03/11/...  2011-03-11
# 4   https://www.abc.net.au/news/2011-04-23/gillard...  2011-04-22
# 5   https://www.bigislandvideonews.com/2011/03/24/...  2011-03-24
# 6   https://www.cbsnews.com/news/proposed-gop-budg...  2011-03-11
# 7   https://www.wired.com/2011/03/albatrosses-tsun...  2011-03-15
# 8   https://www.nytimes.com/2011/03/17/us/17cresce...  2011-03-16
# 9   https://www.oregonlive.com/pacific-northwest-n...  2011-03-11
# 10  https://www.nytimes.com/2011/04/21/world/asia/...  2011-04-20
# 11  https://abcnews.go.com/US/california-man-swept...  2011-03-11
# 12  https://e360.yale.edu/features/tracking_the_de...  2011-03-22
# 13  http://abcnews.go.com/blogs/technology/2011/10...  2011-10-25
# 14  https://www.oregonlive.com/pacific-northwest-n...  2011-03-13
#
#                                         Clean_content  \
# 0   Loading...  March 11, 2011 The tsunami waves u...
# 1   The power of an 8.9 earthquake in Japan genera...
# 2   The tsunami capital of the continental United ...
# 3   Media release | Hawaii County Office of the Ma...
# 4   Prime Minister Julia Gillard has visited a coa...
# 5   Media release | Hawaii Office of the Governor ...
# 6              By Lucy Madison           March 11,...
# 7   Brandon Keim To revist this article, visit My ...
# 8   Advertisement Supported by Crescent City Journ...
# 9   Reports of serious damage are coming from the ...
# 10  Advertisement Supported by Aneyoshi Journal By...
# 11  California docks take a beating and boats smas...
# 12  The devastating tsunami in northeastern Japan ...
# 13  ABC News  The devastating tsunami that hit Jap...
# 14  Leaving his teenage drug abuse behind in Orego...
#
#                                             Sentences  \
# 0   [Loading...  March 11, 2011 The tsunami waves ...
# 1   [The power of an 8.9 earthquake in Japan gener...
# 2   [The tsunami capital of the continental United...
# 3   [Media release | Hawaii County Office of the M...
# 4   [Prime Minister Julia Gillard has visited a co...
# 5   [Media release | Hawaii Office of the Governor...
# 6   [By Lucy Madison           March 11, 2011 / 4:...
# 7   [Brandon Keim To revist this article, visit My...
# 8   [Advertisement Supported by Crescent City Jour...
# 9   [Reports of serious damage are coming from the...
# 10  [Advertisement Supported by Aneyoshi Journal B...
# 11  [California docks take a beating and boats sma...
# 12  [The devastating tsunami in northeastern Japan...
# 13  [ABC News  The devastating tsunami that hit Ja...
# 14  [Leaving his teenage drug abuse behind in Oreg...
#
#                                              Location  \
# 0   [Japan, America, Crescent City, Calif., Oregon...
# 1   [Japan, California, Santa Cruz, Crescent City,...
# 2   [United States, Crescent City, Calif., Oregon,...
# 3   [the Hawaiian Islands, the County of, Japan, W...
# 4   [Japan, Minami Sanriku, Australia, Sydney, Min...
# 5   [Honolulu, Hawaii Island, the Big Island, Hawa...
# 6                                     [Japan, Hawaii]
# 7              [Honolulu, Tokyo, U.S., Alaska, Leary]
# 8   [CRESCENT CITY, Calif., Crescent City, Tsunami...
# 9   [Japan, Tsunami, Oregon, Curry County, Gold Be...
# 10          [Japan, Kyoto, Jogan, Hiroshima, Morioka]
# 11  [California, Santa Cruz, Oregon, U.S., Brookin...
# 12  [Japan, United States, California, Tokyo, Hons...
# 13  [Japan, the United States, Texas, Midway Islan...
# 14   [Oregon, California, Japan, Crescent City, Bend]
#
#                      QA_location
# 0                    japan coast
# 1      northern california coast
# 2        crescent city , calif .
# 3           the hawaiian islands
# 4                           send
# 5                 the big island
# 6                          japan
# 7                         midway
# 8                          japan
# 9                          japan
# 10              aneyoshi , japan
# 11  santa cruz and crescent city
# 12            northeastern japan
# 13                         japan
# 14                   japan coast

# %%
nb_sentences = 9
df_location = add_QA_impact_to_df(df_location, subject, nb_sentences)
df_location
# Out:
#                                                 Title  \
# 0   California harbor 'destroyed' by tsunami, but ...
# 1   Tsunami Causes Heavy Damage to Crescent City H...
# 2   Tsunamis in the United States have hit Crescen...
# 3   Hawaii County surveys tsunami damage, Kona hit...
# 4   Gillard sees tsunami devastation first hand - ...
# 5   Hawaii says tsunami damage cost $30.6 million,...
# 6   \n    Proposed GOP budget cuts target tsunami ...
# 7    Midway's Albatrosses Survive the Tsunami | WIRED
# 8   Crescent City, Calif., Recovers From Its Own T...
# 9   Oregon Coast tsunami: Serious damage reports f...
# 10  On Stones in Japan, Tsunami Warnings — Aneyosh...
# 11  Search Suspended for California Man Swept Into...
# 12  Tracking the Destructive Power of the Pacific ...
# 13  Tsunami Debris to Hit U.S. Sooner Than Expecte...
# 14  Man swept out to sea by tsunami was Bend nativ...
#
#                                                  Link        Date  \
# 0   https://www.csmonitor.com/USA/2011/0311/Califo...  2011-03-11
# 1   https://www.nbcbayarea.com/news/local/tsunami-...  2011-03-11
# 2   https://slate.com/news-and-politics/2011/03/ts...  2011-03-11
# 3   https://www.bigislandvideonews.com/2011/03/11/...  2011-03-11
# 4   https://www.abc.net.au/news/2011-04-23/gillard...  2011-04-22
# 5   https://www.bigislandvideonews.com/2011/03/24/...  2011-03-24
# 6   https://www.cbsnews.com/news/proposed-gop-budg...  2011-03-11
# 7   https://www.wired.com/2011/03/albatrosses-tsun...  2011-03-15
# 8   https://www.nytimes.com/2011/03/17/us/17cresce...  2011-03-16
# 9   https://www.oregonlive.com/pacific-northwest-n...  2011-03-11
# 10  https://www.nytimes.com/2011/04/21/world/asia/...  2011-04-20
# 11  https://abcnews.go.com/US/california-man-swept...  2011-03-11
# 12  https://e360.yale.edu/features/tracking_the_de...  2011-03-22
# 13  http://abcnews.go.com/blogs/technology/2011/10...  2011-10-25
# 14  https://www.oregonlive.com/pacific-northwest-n...  2011-03-13
#
#                                         Clean_content  \
# 0   Loading...  March 11, 2011 The tsunami waves u...
# 1   The power of an 8.9 earthquake in Japan genera...
# 2   The tsunami capital of the continental United ...
# 3   Media release | Hawaii County Office of the Ma...
# 4   Prime Minister Julia Gillard has visited a coa...
# 5   Media release | Hawaii Office of the Governor ...
# 6              By Lucy Madison           March 11,...
# 7   Brandon Keim To revist this article, visit My ...
# 8   Advertisement Supported by Crescent City Journ...
# 9   Reports of serious damage are coming from the ...
# 10  Advertisement Supported by Aneyoshi Journal By...
# 11  California docks take a beating and boats smas...
# 12  The devastating tsunami in northeastern Japan ...
# 13  ABC News  The devastating tsunami that hit Jap...
# 14  Leaving his teenage drug abuse behind in Orego...
#
#                                             Sentences  \
# 0   [Loading...  March 11, 2011 The tsunami waves ...
# 1   [The power of an 8.9 earthquake in Japan gener...
# 2   [The tsunami capital of the continental United...
# 3   [Media release | Hawaii County Office of the M...
# 4   [Prime Minister Julia Gillard has visited a co...
# 5   [Media release | Hawaii Office of the Governor...
# 6   [By Lucy Madison           March 11, 2011 / 4:...
# 7   [Brandon Keim To revist this article, visit My...
# 8   [Advertisement Supported by Crescent City Jour...
# 9   [Reports of serious damage are coming from the...
# 10  [Advertisement Supported by Aneyoshi Journal B...
# 11  [California docks take a beating and boats sma...
# 12  [The devastating tsunami in northeastern Japan...
# 13  [ABC News  The devastating tsunami that hit Ja...
# 14  [Leaving his teenage drug abuse behind in Oreg...
#
#                                              Location  \
# 0   [Japan, America, Crescent City, Calif., Oregon...
# 1   [Japan, California, Santa Cruz, Crescent City,...
# 2   [United States, Crescent City, Calif., Oregon,...
# 3   [the Hawaiian Islands, the County of, Japan, W...
# 4   [Japan, Minami Sanriku, Australia, Sydney, Min...
# 5   [Honolulu, Hawaii Island, the Big Island, Hawa...
# 6                                     [Japan, Hawaii]
# 7              [Honolulu, Tokyo, U.S., Alaska, Leary]
# 8   [CRESCENT CITY, Calif., Crescent City, Tsunami...
# 9   [Japan, Tsunami, Oregon, Curry County, Gold Be...
# 10          [Japan, Kyoto, Jogan, Hiroshima, Morioka]
# 11  [California, Santa Cruz, Oregon, U.S., Brookin...
# 12  [Japan, United States, California, Tokyo, Hons...
# 13  [Japan, the United States, Texas, Midway Islan...
# 14   [Oregon, California, Japan, Crescent City, Bend]
#
#                      QA_location  \
# 0                    japan coast
# 1      northern california coast
# 2        crescent city , calif .
# 3           the hawaiian islands
# 4                           send
# 5                 the big island
# 6                          japan
# 7                         midway
# 8                          japan
# 9                          japan
# 10              aneyoshi , japan
# 11  santa cruz and crescent city
# 12            northeastern japan
# 13                         japan
# 14                   japan coast
#
#                                             QA_impact
# 0                           destroyed boats and docks
# 1   a wave at 8 : 44 a . m . , measured at 8 . 1 f...
# 2                                             minimal
# 3                                 millions of dollars
# 4   the tsunami claimed thousands of lives in this...
# 5                                     No answer found
# 6         massive tsunami along the nation east coast
# 7                                     nobody was hurt
# 8   damage is believed to be in the tens of millio...
# 9   70 percent of the port commercial basin was de...
# 10  wiped out hundreds of miles of japanese coast ...
# 11  the surge smashed boats and wreck docks in the...
# 12  devastating tsunami in northeastern japan is o...
# 13  houses , boats , cars and entire neighborhoods...
# 14                                                 11
